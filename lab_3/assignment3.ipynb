# %% [markdown]
# # Лабораторная работа 3

# %% [markdown]
# 1) Полносвязная нейронная сеть ( Fully-Connected Neural Network)
#
# 2) Нормализация по мини-батчам (Batch normalization)
#
# 3) Dropout
#
# 4) Сверточные нейронные сети (Convolutional Networks)

# %% [markdown]
# Лабораторные работы можно выполнять с использованием сервиса Google Colaboratory (https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d) или на локальном компьютере.

# %% [markdown]
# # Полносвязная нейронная сеть

# %% [markdown]
# В данной лабораторной работе необходимо будет реализовать полносвязную нейронную сеть, используя модульный подход. Для каждого  слоя реализации прямого и обратного проходов алгоритма обратного распространения ошибки будут иметь следующий вид:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
#
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```

# %%
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from scripts.classifiers.fc_net import *

from scripts.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from scripts.solver import Solver
from scripts.classifiers.cnn import *
from scripts.layers import *
from scripts.fast_layers import *


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)  
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
def print_mean_std(x,axis=0):
    print('  means: ', x.mean(axis=axis))
    print('  stds:  ', x.std(axis=axis))
    print()
# Out:
# =========== You can safely ignore the message below if you are NOT working on ConvolutionalNetworks.ipynb ===========
# 	You will need to compile a Cython extension for a portion of this assignment.
# 	The instructions to do this will be given in a section of the notebook below.
# 	There will be an option for Colab users and another for Jupyter (local) users.

# %% [markdown]
# Загрузите данные из предыдущей лабораторной работы.

# %%
from scripts.data_utils import load_CIFAR10
cifar10_dir = 'scripts/datasets/cifar-10-batches-py'

try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

num_training = 45000
num_validation = 5000
num_test = 1000

mask = list(range(num_training, num_training + num_validation))
X_val = X_train[mask]
y_val = y_train[mask]
mask = list(range(num_training))
X_train = X_train[mask]
y_train = y_train[mask]
mask = list(range(num_test))
X_test = X_test[mask]
y_test = y_test[mask]

mean_image = np.mean(X_train, axis=0)
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image

X_train = X_train.reshape(num_training, -1)
X_val = X_val.reshape(num_validation, -1)
X_test = X_test.reshape(num_test, -1)

print('Train data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
# Out:
# /Users/george/PycharmProjects/AI/lab_3/scripts/data_utils.py:16: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   return pickle.load(f, encoding="latin1")
# Train data shape:  (45000, 3072)
# Validation data shape:  (5000, 3072)
# Test data shape:  (1000, 3072)

# %% [markdown]
# Для полносвязного слоя реализуйте прямой проход (метод affine_forward в scripts/layers.py). Протестируйте свою реализацию.

# %%
num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])


print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  9.769849468192957e-10

# %% [markdown]
# Для полносвязного слоя реализуйте обратный проход (метод affine_backward в scripts/layers.py). Протестируйте свою реализацию.

# %%
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  9.579607670311995e-11
# dw error:  1.2604803862099753e-10
# db error:  7.72167374950876e-11

# %% [markdown]
# Реализуйте прямой проход для слоя активации ReLU (relu_forward) и протестируйте его.

# %%
x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# Реализуйте обратный проход для слоя активации ReLU (relu_backward ) и протестируйте его.

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# В скрипте /layer_utils.py приведены реализации прямого и обратного проходов для часто используемых комбинаций слоев. Например, за полносвязным слоем часто следует слой активации. Ознакомьтесь с функциями affine_relu_forward и affine_relu_backward, запустите код ниже и убедитесь, что ошибка порядка e-10 или ниже.

# %%
from scripts.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  1.70644420803027e-10
# dw error:  8.162088973990222e-11
# db error:  7.82672402145899e-12

# %% [markdown]
# Реализуйте двухслойную полносвязную сеть - класс TwoLayerNet в scripts/classifiers/fc_net.py . Проверьте свою реализацию, запустив код ниже.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.22e-08
# W2 relative error: 3.77e-10
# b1 relative error: 9.83e-09
# b2 relative error: 1.94e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 1.37e-07
# b1 relative error: 1.56e-08
# b2 relative error: 9.09e-10

# %% [markdown]
# Ознакомьтесь с API для обучения и тестирования моделей в scripts/solver.py . Используйте экземпляр класса Solver для обучения двухслойной полносвязной сети. Необходимо достичь минимум 50% верно классифицированных объектов на валидационном наборе.

# %%
model = TwoLayerNet(hidden_dim=100, weight_scale=1e-2, reg=0.5)
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

data = {
    'X_train': X_train,
    'y_train': y_train,
    'X_val': X_val,
    'y_val': y_val,
}

solver = Solver(
    model,
    data,
    update_rule='sgd',
    optim_config={
        'learning_rate': 1e-3,
    },
    lr_decay=0.95,
    num_epochs=20,
    batch_size=100,
    print_every=100,
    verbose=True
    )
solver.train()

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 9000) loss: 11.395170
# (Epoch 0 / 20) train acc: 0.127000; val_acc: 0.135200
# (Iteration 101 / 9000) loss: 8.728186
# (Iteration 201 / 9000) loss: 7.817756
# (Iteration 301 / 9000) loss: 7.256366
# (Iteration 401 / 9000) loss: 6.977553
# (Epoch 1 / 20) train acc: 0.373000; val_acc: 0.399800
# (Iteration 501 / 9000) loss: 6.229012
# (Iteration 601 / 9000) loss: 5.959720
# (Iteration 701 / 9000) loss: 5.312976
# (Iteration 801 / 9000) loss: 5.092700
# (Epoch 2 / 20) train acc: 0.459000; val_acc: 0.441200
# (Iteration 901 / 9000) loss: 4.665722
# (Iteration 1001 / 9000) loss: 4.393480
# (Iteration 1101 / 9000) loss: 4.300312
# (Iteration 1201 / 9000) loss: 4.022372
# (Iteration 1301 / 9000) loss: 3.722311
# (Epoch 3 / 20) train acc: 0.519000; val_acc: 0.477800
# (Iteration 1401 / 9000) loss: 3.485669
# (Iteration 1501 / 9000) loss: 3.401079
# (Iteration 1601 / 9000) loss: 3.341530
# (Iteration 1701 / 9000) loss: 3.118205
# (Epoch 4 / 20) train acc: 0.510000; val_acc: 0.482200
# (Iteration 1801 / 9000) loss: 2.921790
# (Iteration 1901 / 9000) loss: 2.894698
# (Iteration 2001 / 9000) loss: 2.602960
# (Iteration 2101 / 9000) loss: 2.555889
# (Iteration 2201 / 9000) loss: 2.253211
# (Epoch 5 / 20) train acc: 0.528000; val_acc: 0.489400
# (Iteration 2301 / 9000) loss: 2.479095
# (Iteration 2401 / 9000) loss: 2.228718
# (Iteration 2501 / 9000) loss: 2.351352
# (Iteration 2601 / 9000) loss: 2.260315
# (Epoch 6 / 20) train acc: 0.517000; val_acc: 0.478800
# (Iteration 2701 / 9000) loss: 2.105833
# (Iteration 2801 / 9000) loss: 2.237849
# (Iteration 2901 / 9000) loss: 1.801757
# (Iteration 3001 / 9000) loss: 2.054849
# (Iteration 3101 / 9000) loss: 1.876084
# (Epoch 7 / 20) train acc: 0.549000; val_acc: 0.495600
# (Iteration 3201 / 9000) loss: 1.902051
# (Iteration 3301 / 9000) loss: 1.842977
# (Iteration 3401 / 9000) loss: 1.893458
# (Iteration 3501 / 9000) loss: 1.695243
# (Epoch 8 / 20) train acc: 0.572000; val_acc: 0.505600
# (Iteration 3601 / 9000) loss: 1.649665
# (Iteration 3701 / 9000) loss: 1.948147
# (Iteration 3801 / 9000) loss: 1.715612
# (Iteration 3901 / 9000) loss: 1.706791
# (Iteration 4001 / 9000) loss: 1.647117
# (Epoch 9 / 20) train acc: 0.562000; val_acc: 0.493000
# (Iteration 4101 / 9000) loss: 1.876827
# (Iteration 4201 / 9000) loss: 1.587482
# (Iteration 4301 / 9000) loss: 1.769213
# (Iteration 4401 / 9000) loss: 1.594664
# (Epoch 10 / 20) train acc: 0.564000; val_acc: 0.506000
# (Iteration 4501 / 9000) loss: 1.466372
# (Iteration 4601 / 9000) loss: 1.658469
# (Iteration 4701 / 9000) loss: 1.699254
# (Iteration 4801 / 9000) loss: 1.739185
# (Iteration 4901 / 9000) loss: 1.503700
# (Epoch 11 / 20) train acc: 0.564000; val_acc: 0.492800
# (Iteration 5001 / 9000) loss: 1.573806
# (Iteration 5101 / 9000) loss: 1.538148
# (Iteration 5201 / 9000) loss: 1.594516
# (Iteration 5301 / 9000) loss: 1.445448
# (Epoch 12 / 20) train acc: 0.594000; val_acc: 0.511200
# (Iteration 5401 / 9000) loss: 1.515550
# (Iteration 5501 / 9000) loss: 1.454993
# (Iteration 5601 / 9000) loss: 1.527267
# (Iteration 5701 / 9000) loss: 1.436222
# (Iteration 5801 / 9000) loss: 1.484388
# (Epoch 13 / 20) train acc: 0.599000; val_acc: 0.520200
# (Iteration 5901 / 9000) loss: 1.575351
# (Iteration 6001 / 9000) loss: 1.542202
# (Iteration 6101 / 9000) loss: 1.418951
# (Iteration 6201 / 9000) loss: 1.499654
# (Epoch 14 / 20) train acc: 0.616000; val_acc: 0.516400
# (Iteration 6301 / 9000) loss: 1.602881
# (Iteration 6401 / 9000) loss: 1.348782
# (Iteration 6501 / 9000) loss: 1.463560
# (Iteration 6601 / 9000) loss: 1.594579
# (Iteration 6701 / 9000) loss: 1.261266
# (Epoch 15 / 20) train acc: 0.602000; val_acc: 0.518400
# (Iteration 6801 / 9000) loss: 1.364353
# (Iteration 6901 / 9000) loss: 1.357185
# (Iteration 7001 / 9000) loss: 1.408725
# (Iteration 7101 / 9000) loss: 1.287000
# (Epoch 16 / 20) train acc: 0.611000; val_acc: 0.517600
# (Iteration 7201 / 9000) loss: 1.283963
# (Iteration 7301 / 9000) loss: 1.529271
# (Iteration 7401 / 9000) loss: 1.250914
# (Iteration 7501 / 9000) loss: 1.418649
# (Iteration 7601 / 9000) loss: 1.426085
# (Epoch 17 / 20) train acc: 0.634000; val_acc: 0.515400
# (Iteration 7701 / 9000) loss: 1.490208
# (Iteration 7801 / 9000) loss: 1.505563
# (Iteration 7901 / 9000) loss: 1.303859
# (Iteration 8001 / 9000) loss: 1.473065
# (Epoch 18 / 20) train acc: 0.592000; val_acc: 0.517000
# (Iteration 8101 / 9000) loss: 1.206896
# (Iteration 8201 / 9000) loss: 1.376272
# (Iteration 8301 / 9000) loss: 1.276401
# (Iteration 8401 / 9000) loss: 1.252827
# (Iteration 8501 / 9000) loss: 1.527980
# (Epoch 19 / 20) train acc: 0.608000; val_acc: 0.531600
# (Iteration 8601 / 9000) loss: 1.377505
# (Iteration 8701 / 9000) loss: 1.316642
# (Iteration 8801 / 9000) loss: 1.340055
# (Iteration 8901 / 9000) loss: 1.513046
# (Epoch 20 / 20) train acc: 0.619000; val_acc: 0.526400

# %%
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# Теперь реализуйте полносвязную сеть с произвольным числом скрытых слоев. Ознакомьтесь с классом FullyConnectedNet в scripts/classifiers/fc_net.py . Реализуйте инициализацию, прямой и обратный проходы.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)
  
  # Most of the errors should be on the order of e-7 or smaller.   
  # NOTE: It is fine however to see an error for W2 on the order of e-5
  # for the check when reg = 0.0
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 1.48e-07
# W2 relative error: 2.21e-05
# W3 relative error: 3.53e-07
# b1 relative error: 5.38e-09
# b2 relative error: 2.09e-09
# b3 relative error: 5.80e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 3.90e-09
# W2 relative error: 3.52e-08
# W3 relative error: 1.32e-08
# b1 relative error: 1.48e-08
# b2 relative error: 1.72e-09
# b3 relative error: 1.57e-10

# %% [markdown]
# Попробуйте добиться эффекта переобучения на небольшом наборе изображений (например, 50). Используйте трехслойную сеть со 100 нейронами на каждом скрытом слое. Попробуйте переобучить сеть, достигнув 100 % accuracy за 20 эпох. Для этого поэкспериментируйте с параметрами weight_scale и learning_rate.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

# Больше шагов на эпоху (batch_size=10) помогает переобучиться за 20 эпох
search_space = [
    (1e-1, 1e-2),
    (7e-2, 1e-2),
    (5e-2, 1e-2),
    (3e-2, 1e-2),
    (1e-1, 5e-3),
    (7e-2, 5e-3),
    (5e-2, 5e-3),
    (3e-2, 5e-3),
    (1e-1, 2e-3),
    (7e-2, 2e-3),
    (5e-2, 2e-3),
    (3e-2, 2e-3),
]

best = None
for weight_scale, learning_rate in search_space:
    model_try = FullyConnectedNet([100, 100], weight_scale=weight_scale, dtype=np.float64)
    solver_try = Solver(
        model_try,
        small_data,
        print_every=1000, num_epochs=20, batch_size=10,
        update_rule='sgd',
        optim_config={
          'learning_rate': learning_rate,
        },
        verbose=False
    )
    solver_try.train()
    train_acc_max = max(solver_try.train_acc_history)
    val_acc_at_end = solver_try.val_acc_history[-1]

    if np.isnan(train_acc_max):
        train_acc_max = -1.0

    print('weight_scale=%.3g lr=%.3g -> max train acc=%.3f, final val acc=%.3f' % (
        weight_scale, learning_rate, train_acc_max, val_acc_at_end
    ))

    if best is None or train_acc_max > best['train_acc_max']:
        best = {
            'weight_scale': weight_scale,
            'learning_rate': learning_rate,
            'train_acc_max': train_acc_max,
        }

weight_scale = best['weight_scale']
learning_rate = best['learning_rate']
print('\nBest hyperparams: weight_scale=%.3g, learning_rate=%.3g (max train acc=%.3f)' % (
    weight_scale, learning_rate, best['train_acc_max']
))

# Финальный запуск с лучшими гиперпараметрами
model = FullyConnectedNet([100, 100], weight_scale=weight_scale, dtype=np.float64)
solver = Solver(
    model, small_data,
    print_every=20, num_epochs=20, batch_size=10,
    update_rule='sgd',
    optim_config={
      'learning_rate': learning_rate,
    },
    verbose=True
 )
solver.train()

print('Final max train accuracy:', max(solver.train_acc_history))
# Out:
# /Users/george/PycharmProjects/AI/lab_3/scripts/layers.py:820: RuntimeWarning: invalid value encountered in subtract
#   shifted_logits = x - np.max(x, axis=1, keepdims=True)
# /Users/george/PycharmProjects/AI/lab_3/scripts/classifiers/fc_net.py:349: RuntimeWarning: overflow encountered in multiply
#   loss += 0.5 * self.reg * np.sum(self.params[w_key] * self.params[w_key])
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/george/PycharmProjects/AI/lab_3/scripts/classifiers/fc_net.py:349: RuntimeWarning: invalid value encountered in scalar multiply
#   loss += 0.5 * self.reg * np.sum(self.params[w_key] * self.params[w_key])
# weight_scale=0.1 lr=0.01 -> max train acc=0.160, final val acc=0.099
# weight_scale=0.07 lr=0.01 -> max train acc=0.180, final val acc=0.096
# weight_scale=0.05 lr=0.01 -> max train acc=0.180, final val acc=0.099
# weight_scale=0.03 lr=0.01 -> max train acc=0.180, final val acc=0.096
# weight_scale=0.1 lr=0.005 -> max train acc=0.220, final val acc=0.107
# weight_scale=0.07 lr=0.005 -> max train acc=0.220, final val acc=0.097
# weight_scale=0.05 lr=0.005 -> max train acc=0.360, final val acc=0.099
# weight_scale=0.03 lr=0.005 -> max train acc=1.000, final val acc=0.158
# weight_scale=0.1 lr=0.002 -> max train acc=0.320, final val acc=0.112
# weight_scale=0.07 lr=0.002 -> max train acc=0.880, final val acc=0.134
# weight_scale=0.05 lr=0.002 -> max train acc=1.000, final val acc=0.139
# weight_scale=0.03 lr=0.002 -> max train acc=1.000, final val acc=0.164
#
# Best hyperparams: weight_scale=0.03, learning_rate=0.005 (max train acc=1.000)
# (Iteration 1 / 100) loss: 10.320677
# (Epoch 0 / 20) train acc: 0.260000; val_acc: 0.107800
# (Epoch 1 / 20) train acc: 0.320000; val_acc: 0.119200
# (Epoch 2 / 20) train acc: 0.700000; val_acc: 0.152200
# (Epoch 3 / 20) train acc: 0.740000; val_acc: 0.169400
# (Epoch 4 / 20) train acc: 0.840000; val_acc: 0.150200
# (Iteration 21 / 100) loss: 0.596568
# (Epoch 5 / 20) train acc: 0.900000; val_acc: 0.160600
# (Epoch 6 / 20) train acc: 0.960000; val_acc: 0.170600
# (Epoch 7 / 20) train acc: 0.920000; val_acc: 0.167200
# (Epoch 8 / 20) train acc: 1.000000; val_acc: 0.165600
# (Iteration 41 / 100) loss: 0.154711
# (Epoch 9 / 20) train acc: 1.000000; val_acc: 0.165200
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.162000
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.161400
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.166800
# (Iteration 61 / 100) loss: 0.009216
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.169600
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.165800
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.166800
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.168200
# (Iteration 81 / 100) loss: 0.007233
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.169400
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.171000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.170400
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.170600
# Final max train accuracy: 1.0

# %% [markdown]
# Повторите эксперимент, описанный выше, для пятислойной сети.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

# Для более глубокой сети подбираем параметры осторожнее
search_space = [
    (1e-1, 1e-3),
    (7e-2, 1e-3),
    (5e-2, 1e-3),
    (3e-2, 1e-3),
    (1e-1, 2e-3),
    (7e-2, 2e-3),
    (5e-2, 2e-3),
    (3e-2, 2e-3),
    (2e-2, 5e-3),
    (1e-2, 5e-3),
    (2e-2, 1e-2),
    (1e-2, 1e-2),
]

best = None
for weight_scale, learning_rate in search_space:
    model_try = FullyConnectedNet([100, 100, 100, 100], weight_scale=weight_scale, dtype=np.float64)
    solver_try = Solver(
        model_try,
        small_data,
        print_every=1000, num_epochs=20, batch_size=10,
        update_rule='sgd',
        optim_config={
          'learning_rate': learning_rate,
        },
        verbose=False
    )
    solver_try.train()

    train_acc_max = max(solver_try.train_acc_history)
    val_acc_end = solver_try.val_acc_history[-1]
    if np.isnan(train_acc_max):
        train_acc_max = -1.0

    print('weight_scale=%.3g lr=%.3g -> max train acc=%.3f, final val acc=%.3f' % (
        weight_scale, learning_rate, train_acc_max, val_acc_end
    ))

    if best is None or train_acc_max > best['train_acc_max']:
        best = {
            'weight_scale': weight_scale,
            'learning_rate': learning_rate,
            'train_acc_max': train_acc_max,
        }

weight_scale = best['weight_scale']
learning_rate = best['learning_rate']
print('\nBest hyperparams: weight_scale=%.3g, learning_rate=%.3g (max train acc=%.3f)' % (
    weight_scale, learning_rate, best['train_acc_max']
))

# Финальный запуск с лучшими параметрами
model = FullyConnectedNet([100, 100, 100, 100],
                weight_scale=weight_scale, dtype=np.float64)
solver = Solver(model, small_data,
                print_every=20, num_epochs=20, batch_size=10,
                update_rule='sgd',
                optim_config={
                  'learning_rate': learning_rate,
                },
                verbose=True
         )
solver.train()

print('Final max train accuracy:', max(solver.train_acc_history))

plt.plot(solver.loss_history, 'o')
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.show()
# Out:
# weight_scale=0.1 lr=0.001 -> max train acc=1.000, final val acc=0.136
# weight_scale=0.07 lr=0.001 -> max train acc=1.000, final val acc=0.117
# weight_scale=0.05 lr=0.001 -> max train acc=1.000, final val acc=0.134
# weight_scale=0.03 lr=0.001 -> max train acc=0.480, final val acc=0.118
# weight_scale=0.1 lr=0.002 -> max train acc=0.980, final val acc=0.117
# weight_scale=0.07 lr=0.002 -> max train acc=1.000, final val acc=0.144
# weight_scale=0.05 lr=0.002 -> max train acc=1.000, final val acc=0.130
# weight_scale=0.03 lr=0.002 -> max train acc=0.560, final val acc=0.155
# weight_scale=0.02 lr=0.005 -> max train acc=0.380, final val acc=0.155
# weight_scale=0.01 lr=0.005 -> max train acc=0.200, final val acc=0.096
# weight_scale=0.02 lr=0.01 -> max train acc=0.600, final val acc=0.158
# weight_scale=0.01 lr=0.01 -> max train acc=0.180, final val acc=0.104
#
# Best hyperparams: weight_scale=0.1, learning_rate=0.001 (max train acc=1.000)
# (Iteration 1 / 100) loss: 147.545533
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.115600
# (Epoch 1 / 20) train acc: 0.320000; val_acc: 0.093800
# (Epoch 2 / 20) train acc: 0.460000; val_acc: 0.119600
# (Epoch 3 / 20) train acc: 0.620000; val_acc: 0.137800
# (Epoch 4 / 20) train acc: 0.780000; val_acc: 0.140200
# (Iteration 21 / 100) loss: 9.614300
# (Epoch 5 / 20) train acc: 0.820000; val_acc: 0.140400
# (Epoch 6 / 20) train acc: 0.840000; val_acc: 0.133800
# (Epoch 7 / 20) train acc: 0.980000; val_acc: 0.135600
# (Epoch 8 / 20) train acc: 0.980000; val_acc: 0.128800
# (Iteration 41 / 100) loss: 0.000000
# (Epoch 9 / 20) train acc: 0.980000; val_acc: 0.129600
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.133200
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.133200
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.134000
# (Iteration 61 / 100) loss: 0.000001
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.134200
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.133800
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.134200
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.134000
# (Iteration 81 / 100) loss: 0.000045
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.134000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.133800
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.133800
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.134000
# Final max train accuracy: 1.0

# %% [markdown]
# Сделайте выводы по проведенному эксперименту.

# %% [markdown]
# ### Выводы по эксперименту
#
# В эксперименте проверялась способность полносвязной нейронной сети полностью запомнить маленькую обучающую выборку из 50 изображений.
#
# Для трехслойной сети с двумя скрытыми слоями по 100 нейронов удалось добиться полного переобучения. Лучший результат был получен при параметрах:
#
# weight_scale = 0.03
# learning_rate = 0.005
#
# Максимальная точность на обучающей выборке достигла 1.0, то есть сеть правильно классифицировала все 50 обучающих изображений. При этом значение функции потерь заметно уменьшилось: с начального значения около 10.32 до значений, близких к нулю.
#
# Для пятислойной сети также удалось получить 100% точность на обучающей выборке. Лучшие параметры:
#
# weight_scale = 0.1
# learning_rate = 0.001
#
# Функция потерь также снизилась почти до нуля, что показывает, что сеть полностью запомнила обучающие примеры.
#
# Однако качество на валидационной выборке осталось низким: примерно 0.13–0.17. Это означает, что модель хорошо запомнила маленький набор данных, но плохо обобщает результат на новые изображения.
#
# Итоговый вывод: обе сети успешно переобучились на 50 изображениях. Это подтверждает корректность реализации обучения, прямого и обратного прохода. При этом эксперимент показывает классический эффект переобучения: высокая точность на train не означает хорошее качество на validation.

# %% [markdown]
# Ранее обновление весов проходило по правилу SGD. Теперь попробуйте реализовать стохастический градиентный спуск с импульсом (SGD+momentum). http://cs231n.github.io/neural-networks-3/#sgd Реализуйте sgd_momentum в scripts/optim.py  и запустите проверку.

# %%
from scripts.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print('next_w error: ', rel_error(next_w, expected_next_w))
print('velocity error: ', rel_error(expected_velocity, config['velocity']))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Сравните результаты обучения шестислойной сети, обученной классическим градиентным спуском и адаптивным алгоритмом с импульсом. Какой алгоритм сходится быстрее.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 5e-3,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.items():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label="loss_%s" % update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label="train_acc_%s" % update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label="val_acc_%s" % update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  sgd
# (Iteration 1 / 200) loss: 2.696289
# (Epoch 0 / 5) train acc: 0.078000; val_acc: 0.104800
# (Iteration 11 / 200) loss: 2.255191
# (Iteration 21 / 200) loss: 2.228659
# (Iteration 31 / 200) loss: 2.125316
# (Epoch 1 / 5) train acc: 0.240000; val_acc: 0.213200
# (Iteration 41 / 200) loss: 2.147887
# (Iteration 51 / 200) loss: 2.107023
# (Iteration 61 / 200) loss: 2.129670
# (Iteration 71 / 200) loss: 2.008470
# (Epoch 2 / 5) train acc: 0.306000; val_acc: 0.259600
# (Iteration 81 / 200) loss: 1.877533
# (Iteration 91 / 200) loss: 2.075343
# (Iteration 101 / 200) loss: 1.893369
# (Iteration 111 / 200) loss: 1.847593
# (Epoch 3 / 5) train acc: 0.336000; val_acc: 0.281200
# (Iteration 121 / 200) loss: 1.904143
# (Iteration 131 / 200) loss: 1.781566
# (Iteration 141 / 200) loss: 1.937158
# (Iteration 151 / 200) loss: 1.797189
# (Epoch 4 / 5) train acc: 0.352000; val_acc: 0.294200
# (Iteration 161 / 200) loss: 1.655056
# (Iteration 171 / 200) loss: 1.749509
# (Iteration 181 / 200) loss: 1.802819
# (Iteration 191 / 200) loss: 1.774287
# (Epoch 5 / 5) train acc: 0.367000; val_acc: 0.302600
#
# running with  sgd_momentum
# (Iteration 1 / 200) loss: 2.839167
# (Epoch 0 / 5) train acc: 0.120000; val_acc: 0.107200
# (Iteration 11 / 200) loss: 2.284993
# (Iteration 21 / 200) loss: 2.094931
# (Iteration 31 / 200) loss: 1.989257
# (Epoch 1 / 5) train acc: 0.353000; val_acc: 0.262000
# (Iteration 41 / 200) loss: 2.020329
# (Iteration 51 / 200) loss: 1.784358
# (Iteration 61 / 200) loss: 1.765182
# (Iteration 71 / 200) loss: 1.783503
# (Epoch 2 / 5) train acc: 0.404000; val_acc: 0.320000
# (Iteration 81 / 200) loss: 1.645409
# (Iteration 91 / 200) loss: 1.723874
# (Iteration 101 / 200) loss: 1.648825
# (Iteration 111 / 200) loss: 1.543234
# (Epoch 3 / 5) train acc: 0.457000; val_acc: 0.323200
# (Iteration 121 / 200) loss: 1.382206
# (Iteration 131 / 200) loss: 1.409597
# (Iteration 141 / 200) loss: 1.390526
# (Iteration 151 / 200) loss: 1.338376
# (Epoch 4 / 5) train acc: 0.482000; val_acc: 0.342200
# (Iteration 161 / 200) loss: 1.477405
# (Iteration 171 / 200) loss: 1.372706
# (Iteration 181 / 200) loss: 1.349134
# (Iteration 191 / 200) loss: 1.234507
# (Epoch 5 / 5) train acc: 0.512000; val_acc: 0.347000

# %% [markdown]
# Реализуйте алгоритмы RMSProp [1] and Adam [2] с коррекцией смещения  - методы rmsprop и adam .
#
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from scripts.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from scripts.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Обучите пару глубоких сетей с испольованием RMSProp и Adam алгоритмов обновления весов и сравните результаты обучения.

# %%
# Сравнение RMSProp и Adam на одинаковой глубокой сети
np.random.seed(231)

num_train = 4000
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

solvers = {}
for update_rule in ['rmsprop', 'adam']:
    print('running with', update_rule)
    model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)
    solver = Solver(
        model, small_data,
        num_epochs=5, batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 1e-3},
        verbose=True
    )
    solver.train()
    solvers[update_rule] = solver
    print()

# Графики обучения
plt.figure(figsize=(15, 15))
plt.subplot(3, 1, 1)
plt.title('Training loss: RMSProp vs Adam')
plt.xlabel('Iteration')
for update_rule, solver in solvers.items():
    plt.plot(solver.loss_history, 'o', label='loss_%s' % update_rule)
plt.legend(loc='upper right')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')
for update_rule, solver in solvers.items():
    plt.plot(solver.train_acc_history, '-o', label='train_acc_%s' % update_rule)
plt.legend(loc='upper left')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')
for update_rule, solver in solvers.items():
    plt.plot(solver.val_acc_history, '-o', label='val_acc_%s' % update_rule)
plt.legend(loc='upper left')
plt.show()

# Числовое сравнение
for update_rule, solver in solvers.items():
    print('%s: final train_acc=%.4f, final val_acc=%.4f, min loss=%.4f' % (
        update_rule,
        solver.train_acc_history[-1],
        solver.val_acc_history[-1],
        np.min(solver.loss_history)
    ))
# Out:
# running with rmsprop
# (Iteration 1 / 200) loss: 2.730291
# (Epoch 0 / 5) train acc: 0.109000; val_acc: 0.101600
# (Iteration 11 / 200) loss: 2.115156
# (Iteration 21 / 200) loss: 2.047848
# (Iteration 31 / 200) loss: 1.969036
# (Epoch 1 / 5) train acc: 0.304000; val_acc: 0.249800
# (Iteration 41 / 200) loss: 1.944048
# (Iteration 51 / 200) loss: 1.843543
# (Iteration 61 / 200) loss: 1.741234
# (Iteration 71 / 200) loss: 1.740146
# (Epoch 2 / 5) train acc: 0.376000; val_acc: 0.291200
# (Iteration 81 / 200) loss: 1.833011
# (Iteration 91 / 200) loss: 1.964213
# (Iteration 101 / 200) loss: 1.568961
# (Iteration 111 / 200) loss: 1.582227
# (Epoch 3 / 5) train acc: 0.429000; val_acc: 0.328200
# (Iteration 121 / 200) loss: 1.626585
# (Iteration 131 / 200) loss: 1.494309
# (Iteration 141 / 200) loss: 1.613660
# (Iteration 151 / 200) loss: 1.467149
# (Epoch 4 / 5) train acc: 0.477000; val_acc: 0.360000
# (Iteration 161 / 200) loss: 1.262882
# (Iteration 171 / 200) loss: 1.284206
# (Iteration 181 / 200) loss: 1.446842
# (Iteration 191 / 200) loss: 1.448625
# (Epoch 5 / 5) train acc: 0.514000; val_acc: 0.337400
#
# running with adam
# (Iteration 1 / 200) loss: 2.988777
# (Epoch 0 / 5) train acc: 0.135000; val_acc: 0.111000
# (Iteration 11 / 200) loss: 2.161089
# (Iteration 21 / 200) loss: 1.976118
# (Iteration 31 / 200) loss: 1.956970
# (Epoch 1 / 5) train acc: 0.344000; val_acc: 0.297200
# (Iteration 41 / 200) loss: 1.755361
# (Iteration 51 / 200) loss: 1.928374
# (Iteration 61 / 200) loss: 1.668481
# (Iteration 71 / 200) loss: 1.691543
# (Epoch 2 / 5) train acc: 0.432000; val_acc: 0.338600
# (Iteration 81 / 200) loss: 1.699097
# (Iteration 91 / 200) loss: 1.473196
# (Iteration 101 / 200) loss: 1.375835
# (Iteration 111 / 200) loss: 1.446506
# (Epoch 3 / 5) train acc: 0.484000; val_acc: 0.345400
# (Iteration 121 / 200) loss: 1.436208
# (Iteration 131 / 200) loss: 1.425353
# (Iteration 141 / 200) loss: 1.527031
# (Iteration 151 / 200) loss: 1.344817
# (Epoch 4 / 5) train acc: 0.576000; val_acc: 0.348200
# (Iteration 161 / 200) loss: 1.312234
# (Iteration 171 / 200) loss: 0.988734
# (Iteration 181 / 200) loss: 1.016413
# (Iteration 191 / 200) loss: 1.166350
# (Epoch 5 / 5) train acc: 0.531000; val_acc: 0.357000
# rmsprop: final train_acc=0.5140, final val_acc=0.3374, min loss=1.1938
# adam: final train_acc=0.5310, final val_acc=0.3570, min loss=0.9296

# %% [markdown]
# Получите лучшую полносвязную сеть для классификации вашего набора данных. На наборе CIFAR-10 необходимо получить accuracy не ниже 50 % на валидационном наборе.

# %%
best_model = None
################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Используем полный словарь данных (включая test), т.к. ниже есть оценка на test
data = {
    'X_train': X_train,
    'y_train': y_train,
    'X_val': X_val,
    'y_val': y_val,
    'X_test': X_test,
    'y_test': y_test,
}

# Небольшой перебор гиперпараметров на подмножестве для ускорения подбора
num_tune = 12000
tune_data = {
    'X_train': data['X_train'][:num_tune],
    'y_train': data['y_train'][:num_tune],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

candidates = [
    {'hidden_dims': [120, 120], 'weight_scale': 1e-2, 'reg': 5e-4, 'learning_rate': 1e-3},
    {'hidden_dims': [150, 120], 'weight_scale': 8e-3, 'reg': 1e-3, 'learning_rate': 1e-3},
    {'hidden_dims': [200, 150], 'weight_scale': 8e-3, 'reg': 1e-3, 'learning_rate': 8e-4},
    {'hidden_dims': [200, 200], 'weight_scale': 6e-3, 'reg': 2e-3, 'learning_rate': 8e-4},
]

best_cfg = None
best_val = -1
for cfg in candidates:
    model_try = FullyConnectedNet(
        cfg['hidden_dims'],
        input_dim=3072,
        num_classes=10,
        weight_scale=cfg['weight_scale'],
        reg=cfg['reg'],
        dtype=np.float64
    )
    solver_try = Solver(
        model_try,
        tune_data,
        update_rule='adam',
        optim_config={'learning_rate': cfg['learning_rate']},
        lr_decay=0.95,
        num_epochs=8,
        batch_size=200,
        print_every=200,
        verbose=False
    )
    solver_try.train()
    val_peak = max(solver_try.val_acc_history)
    print('cfg=%s -> best val: %.4f' % (cfg, val_peak))

    if val_peak > best_val:
        best_val = val_peak
        best_cfg = cfg

print('\nBest cfg from tuning:', best_cfg, 'val=', best_val)

# Финальное обучение лучшей модели на полном train
best_model = FullyConnectedNet(
    best_cfg['hidden_dims'],
    input_dim=3072,
    num_classes=10,
    weight_scale=best_cfg['weight_scale'],
    reg=best_cfg['reg'],
    dtype=np.float64
)

best_solver = Solver(
    best_model,
    data,
    update_rule='adam',
    optim_config={'learning_rate': best_cfg['learning_rate']},
    lr_decay=0.95,
    num_epochs=12,
    batch_size=200,
    print_every=200,
    verbose=True
)
best_solver.train()

print('Final best validation accuracy:', max(best_solver.val_acc_history))

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# cfg={'hidden_dims': [120, 120], 'weight_scale': 0.01, 'reg': 0.0005, 'learning_rate': 0.001} -> best val: 0.4448
# cfg={'hidden_dims': [150, 120], 'weight_scale': 0.008, 'reg': 0.001, 'learning_rate': 0.001} -> best val: 0.4484
# cfg={'hidden_dims': [200, 150], 'weight_scale': 0.008, 'reg': 0.001, 'learning_rate': 0.0008} -> best val: 0.4436
# cfg={'hidden_dims': [200, 200], 'weight_scale': 0.006, 'reg': 0.002, 'learning_rate': 0.0008} -> best val: 0.4540
#
# Best cfg from tuning: {'hidden_dims': [200, 200], 'weight_scale': 0.006, 'reg': 0.002, 'learning_rate': 0.0008} val= 0.454
# (Iteration 1 / 2700) loss: 2.323974
# (Epoch 0 / 12) train acc: 0.183000; val_acc: 0.180000
# (Iteration 201 / 2700) loss: 1.619719
# (Epoch 1 / 12) train acc: 0.451000; val_acc: 0.448200
# (Iteration 401 / 2700) loss: 1.575045
# (Epoch 2 / 12) train acc: 0.488000; val_acc: 0.476600
# (Iteration 601 / 2700) loss: 1.501980
# (Epoch 3 / 12) train acc: 0.527000; val_acc: 0.477400
# (Iteration 801 / 2700) loss: 1.357640
# (Epoch 4 / 12) train acc: 0.536000; val_acc: 0.494800
# (Iteration 1001 / 2700) loss: 1.416269
# (Epoch 5 / 12) train acc: 0.544000; val_acc: 0.499200
# (Iteration 1201 / 2700) loss: 1.326673
# (Epoch 6 / 12) train acc: 0.574000; val_acc: 0.495000
# (Iteration 1401 / 2700) loss: 1.290640
# (Epoch 7 / 12) train acc: 0.598000; val_acc: 0.507400
# (Iteration 1601 / 2700) loss: 1.310500
# (Epoch 8 / 12) train acc: 0.596000; val_acc: 0.501800
# (Iteration 1801 / 2700) loss: 1.198191
# (Iteration 2001 / 2700) loss: 1.289170
# (Epoch 9 / 12) train acc: 0.633000; val_acc: 0.519400
# (Iteration 2201 / 2700) loss: 1.097512
# (Epoch 10 / 12) train acc: 0.634000; val_acc: 0.514800
# (Iteration 2401 / 2700) loss: 1.159548
# (Epoch 11 / 12) train acc: 0.635000; val_acc: 0.514600
# (Iteration 2601 / 2700) loss: 1.130475
# (Epoch 12 / 12) train acc: 0.635000; val_acc: 0.524400
# Final best validation accuracy: 0.5244

# %% [markdown]
# Получите оценку accuracy для валидационной и тестовой выборок.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.5244
# Test set accuracy:  0.531

# %% [markdown]
# # Нормализация по мини-батчам
#
# Идея нормализации по мини-батчам предложена в работе [1]
#
# [1] Sergey Ioffe and Christian Szegedy, "Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift", ICML 2015.

# %% [markdown]
# Реализуйте прямой проход для слоя батч-нормализации - функция batchnorm_forward в scripts/layers.py . Проверьте свою реализацию, запустив следующий код:

# %%
# Check the training-time forward pass by checking means and variances
# of features both before and after batch normalization   

# Simulate the forward pass for a two-layer network
np.random.seed(231)
N, D1, D2, D3 = 200, 50, 60, 3
X = np.random.randn(N, D1)
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)
a = np.maximum(0, X.dot(W1)).dot(W2)

print('Before batch normalization:')
print_mean_std(a,axis=0)

gamma = np.ones((D3,))
beta = np.zeros((D3,))
# Means should be close to zero and stds close to one
print('After batch normalization (gamma=1, beta=0)')
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=0)

gamma = np.asarray([1.0, 2.0, 3.0])
beta = np.asarray([11.0, 12.0, 13.0])
# Now means should be close to beta and stds close to gamma
print('After batch normalization (gamma=', gamma, ', beta=', beta, ')')
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=0)
# Out:
# Before batch normalization:
#   means:  [ -2.3814598  -13.18038246   1.91780462]
#   stds:   [27.18502186 34.21455511 37.68611762]
#
# After batch normalization (gamma=1, beta=0)
#   means:  [8.88178420e-18 2.27595720e-17 5.30825384e-17]
#   stds:   [0.99999999 1.         1.        ]
#
# After batch normalization (gamma= [1. 2. 3.] , beta= [11. 12. 13.] )
#   means:  [11. 12. 13.]
#   stds:   [0.99999999 1.99999999 2.99999999]

# %%
# Check the test-time forward pass by running the training-time
# forward pass many times to warm up the running averages, and then
# checking the means and variances of activations after a test-time
# forward pass.

np.random.seed(231)
N, D1, D2, D3 = 200, 50, 60, 3
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)

bn_param = {'mode': 'train'}
gamma = np.ones(D3)
beta = np.zeros(D3)

for t in range(50):
  X = np.random.randn(N, D1)
  a = np.maximum(0, X.dot(W1)).dot(W2)
  batchnorm_forward(a, gamma, beta, bn_param)

bn_param['mode'] = 'test'
X = np.random.randn(N, D1)
a = np.maximum(0, X.dot(W1)).dot(W2)
a_norm, _ = batchnorm_forward(a, gamma, beta, bn_param)

# Means should be close to zero and stds close to one, but will be
# noisier than training-time forward passes.
print('After batch normalization (test-time):')
print_mean_std(a_norm,axis=0)
# Out:
# After batch normalization (test-time):
#   means:  [-0.03927354 -0.04349152 -0.10452688]
#   stds:   [1.01531428 1.01238373 0.97819988]

# %% [markdown]
# Реализуйте обратный проход в функции batchnorm_backward.

# %%
# Gradient check batchnorm backward pass
np.random.seed(231)
N, D = 4, 5
x = 5 * np.random.randn(N, D) + 12
gamma = np.random.randn(D)
beta = np.random.randn(D)
dout = np.random.randn(N, D)

bn_param = {'mode': 'train'}
fx = lambda x: batchnorm_forward(x, gamma, beta, bn_param)[0]
fg = lambda a: batchnorm_forward(x, a, beta, bn_param)[0]
fb = lambda b: batchnorm_forward(x, gamma, b, bn_param)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
da_num = eval_numerical_gradient_array(fg, gamma.copy(), dout)
db_num = eval_numerical_gradient_array(fb, beta.copy(), dout)

_, cache = batchnorm_forward(x, gamma, beta, bn_param)
dx, dgamma, dbeta = batchnorm_backward(dout, cache)
#You should expect to see relative errors between 1e-13 and 1e-8
print('dx error: ', rel_error(dx_num, dx))
print('dgamma error: ', rel_error(da_num, dgamma))
print('dbeta error: ', rel_error(db_num, dbeta))
# Out:
# dx error:  1.0906010595521823e-09
# dgamma error:  5.418458160170129e-12
# dbeta error:  2.276445013433725e-12

# %% [markdown]
# Измените реализацию класса FullyConnectedNet, добавив батч-нормализацию.
# Если флаг normalization == "batchnorm", то вам необходимо вставить слой батч-нормализации перед каждым слоем активации ReLU, кроме выхода сети.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

# You should expect losses between 1e-4~1e-10 for W, 
# losses between 1e-08~1e-10 for b,
# and losses between 1e-08~1e-09 for beta and gammas.
for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64,
                            normalization='batchnorm')

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
  if reg == 0: print()
# Out:
# Running check with reg =  0
# Initial loss:  2.2611955101340957
# W1 relative error: 1.10e-04
# W2 relative error: 2.85e-06
# W3 relative error: 3.75e-10
# b1 relative error: 1.33e-07
# b2 relative error: 4.44e-08
# b3 relative error: 9.06e-11
# beta1 relative error: 7.33e-09
# beta2 relative error: 2.67e-09
# gamma1 relative error: 6.96e-09
# gamma2 relative error: 2.41e-09
#
# Running check with reg =  3.14
# Initial loss:  6.996533220108303
# W1 relative error: 1.98e-06
# W2 relative error: 2.28e-06
# W3 relative error: 1.11e-08
# b1 relative error: 1.11e-08
# b2 relative error: 6.66e-08
# b3 relative error: 2.23e-10
# beta1 relative error: 6.65e-09
# beta2 relative error: 5.69e-09
# gamma1 relative error: 5.94e-09
# gamma2 relative error: 4.14e-09

# %% [markdown]
# Обучите 6-ти слойную сеть на наборе из 1000 изображений с батч-нормализацией и без нее

# %%
np.random.seed(231)
# Try training a very deep net with batchnorm
hidden_dims = [100, 100, 100, 100, 100]

num_train = 1000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 2e-2
bn_model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization='batchnorm')
model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)

print('Solver with batch norm:')
bn_solver = Solver(bn_model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True,print_every=20)
bn_solver.train()

print('\nSolver without batch norm:')
solver = Solver(model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=20)
solver.train()
# Out:
# Solver with batch norm:
# (Iteration 1 / 200) loss: 2.294998
# (Epoch 0 / 10) train acc: 0.109000; val_acc: 0.108600
# (Epoch 1 / 10) train acc: 0.337000; val_acc: 0.255200
# (Iteration 21 / 200) loss: 1.977067
# (Epoch 2 / 10) train acc: 0.419000; val_acc: 0.294400
# (Iteration 41 / 200) loss: 2.061917
# (Epoch 3 / 10) train acc: 0.491000; val_acc: 0.291800
# (Iteration 61 / 200) loss: 1.722171
# (Epoch 4 / 10) train acc: 0.546000; val_acc: 0.305400
# (Iteration 81 / 200) loss: 1.395692
# (Epoch 5 / 10) train acc: 0.586000; val_acc: 0.307000
# (Iteration 101 / 200) loss: 1.333199
# (Epoch 6 / 10) train acc: 0.643000; val_acc: 0.322800
# (Iteration 121 / 200) loss: 1.011916
# (Epoch 7 / 10) train acc: 0.733000; val_acc: 0.322600
# (Iteration 141 / 200) loss: 1.174648
# (Epoch 8 / 10) train acc: 0.729000; val_acc: 0.314000
# (Iteration 161 / 200) loss: 0.812367
# (Epoch 9 / 10) train acc: 0.815000; val_acc: 0.334200
# (Iteration 181 / 200) loss: 0.704351
# (Epoch 10 / 10) train acc: 0.817000; val_acc: 0.330000
#
# Solver without batch norm:
# (Iteration 1 / 200) loss: 2.302504
# (Epoch 0 / 10) train acc: 0.141000; val_acc: 0.129000
# (Epoch 1 / 10) train acc: 0.263000; val_acc: 0.228000
# (Iteration 21 / 200) loss: 2.044917
# (Epoch 2 / 10) train acc: 0.318000; val_acc: 0.260600
# (Iteration 41 / 200) loss: 1.825160
# (Epoch 3 / 10) train acc: 0.348000; val_acc: 0.259600
# (Iteration 61 / 200) loss: 1.689978
# (Epoch 4 / 10) train acc: 0.376000; val_acc: 0.274600
# (Iteration 81 / 200) loss: 1.631650
# (Epoch 5 / 10) train acc: 0.468000; val_acc: 0.304200
# (Iteration 101 / 200) loss: 1.559521
# (Epoch 6 / 10) train acc: 0.511000; val_acc: 0.311400
# (Iteration 121 / 200) loss: 1.356917
# (Epoch 7 / 10) train acc: 0.509000; val_acc: 0.307400
# (Iteration 141 / 200) loss: 1.536152
# (Epoch 8 / 10) train acc: 0.578000; val_acc: 0.311200
# (Iteration 161 / 200) loss: 1.303837
# (Epoch 9 / 10) train acc: 0.619000; val_acc: 0.311000
# (Iteration 181 / 200) loss: 1.011833
# (Epoch 10 / 10) train acc: 0.687000; val_acc: 0.313400

# %% [markdown]
# Визуализируйте процесс обучения для двух сетей. Увеличилась ли скорость сходимости в случае с батч-нормализацией? Сделайте выводы.

# %%
def plot_training_history(title, label, baseline, bn_solvers, plot_fn, bl_marker='.', bn_marker='.', labels=None):
    """utility function for plotting training history"""
    plt.title(title)
    plt.xlabel(label)
    bn_plots = [plot_fn(bn_solver) for bn_solver in bn_solvers]
    bl_plot = plot_fn(baseline)
    num_bn = len(bn_plots)
    for i in range(num_bn):
        label='with_norm'
        if labels is not None:
            label += str(labels[i])
        plt.plot(bn_plots[i], bn_marker, label=label)
    label='baseline'
    if labels is not None:
        label += str(labels[0])
    plt.plot(bl_plot, bl_marker, label=label)
    plt.legend(loc='lower center', ncol=num_bn+1) 

    
plt.subplot(3, 1, 1)
plot_training_history('Training loss','Iteration', solver, [bn_solver], \
                      lambda x: x.loss_history, bl_marker='o', bn_marker='o')
plt.subplot(3, 1, 2)
plot_training_history('Training accuracy','Epoch', solver, [bn_solver], \
                      lambda x: x.train_acc_history, bl_marker='-o', bn_marker='-o')
plt.subplot(3, 1, 3)
plot_training_history('Validation accuracy','Epoch', solver, [bn_solver], \
                      lambda x: x.val_acc_history, bl_marker='-o', bn_marker='-o')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# #### Выводы по сравнению сети с batch normalization и без
#
# 1. Сеть с batch normalization сходится быстрее: функция потерь убывает быстрее и достигает меньших значений.
# 2. На обучающей выборке batch normalization дает заметно более высокую точность к концу обучения.
# 3. На валидационной выборке также наблюдается небольшой, но устойчивый прирост точности.
# 4. Batch normalization стабилизирует обучение глубокой сети и ускоряет оптимизацию, особенно на ранних эпохах.

# %% [markdown]
# Обучите 6-тислойную сеть с батч-нормализацией и без нее, используя разные размеры батча. Визуализируйте графики обучения. Сделайте выводы по результатам эксперимента.

# %%
def run_batchsize_experiments(normalization_mode):
    np.random.seed(231)
    # Try training a very deep net with batchnorm
    hidden_dims = [100, 100, 100, 100, 100]
    num_train = 1000
    small_data = {
      'X_train': data['X_train'][:num_train],
      'y_train': data['y_train'][:num_train],
      'X_val': data['X_val'],
      'y_val': data['y_val'],
    }
    n_epochs=10
    weight_scale = 2e-2
    batch_sizes = [5,10,50]
    lr = 10**(-3.5)
    solver_bsize = batch_sizes[0]

    print('No normalization: batch size = ',solver_bsize)
    model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)
    solver = Solver(model, small_data,
                    num_epochs=n_epochs, batch_size=solver_bsize,
                    update_rule='adam',
                    optim_config={
                      'learning_rate': lr,
                    },
                    verbose=False)
    solver.train()
    
    bn_solvers = []
    for i in range(len(batch_sizes)):
        b_size=batch_sizes[i]
        print('Normalization: batch size = ',b_size)
        bn_model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=normalization_mode)
        bn_solver = Solver(bn_model, small_data,
                        num_epochs=n_epochs, batch_size=b_size,
                        update_rule='adam',
                        optim_config={
                          'learning_rate': lr,
                        },
                        verbose=False)
        bn_solver.train()
        bn_solvers.append(bn_solver)
        
    return bn_solvers, solver, batch_sizes

batch_sizes = [5,10,50]
bn_solvers_bsize, solver_bsize, batch_sizes = run_batchsize_experiments('batchnorm')
# Out:
# No normalization: batch size =  5
# Normalization: batch size =  5
# Normalization: batch size =  10
# Normalization: batch size =  50

# %%
plt.subplot(2, 1, 1)
plot_training_history('Training accuracy (Batch Normalization)','Epoch', solver_bsize, bn_solvers_bsize, \
                      lambda x: x.train_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)
plt.subplot(2, 1, 2)
plot_training_history('Validation accuracy (Batch Normalization)','Epoch', solver_bsize, bn_solvers_bsize, \
                      lambda x: x.val_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)

plt.gcf().set_size_inches(15, 10)
plt.show()

# %% [markdown]
# ### Выводы по эксперименту
#
# В эксперименте проверялось влияние размера mini-batch на обучение сети с batch normalization. Были рассмотрены размеры batch:
#
# 5, 10, 50
#
# По графикам видно, что при batch size 50 обучение проходило наиболее стабильно. Такая модель быстрее набирала точность на обучающей выборке и к концу обучения показала лучший train accuracy среди вариантов с batch normalization.
#
# При batch size 5 обучение было менее стабильным и более медленным. Это связано с тем, что batch normalization рассчитывает среднее и дисперсию по mini-batch. Если batch слишком маленький, эти статистики становятся шумными, поэтому нормализация работает хуже.
#
# На валидационной выборке все варианты с batch normalization дали близкие результаты, примерно около 0.30–0.33. Однако batch size 50 выглядел наиболее устойчивым вариантом: качество росло ровнее, без сильных колебаний.
#
# Итоговый вывод: для сети с batch normalization слишком маленький batch хуже подходит, потому что статистики нормализации становятся менее надежными. В данном эксперименте batch size 50 оказался наиболее удачным вариантом по стабильности и динамике обучения.

# %% [markdown]
# # Dropout

# %% [markdown]
# Реализуйте прямой проход для dropout-слоя в scripts/layers.py
#
# http://cs231n.github.io/neural-networks-2/#reg

# %%
np.random.seed(231)
x = np.random.randn(500, 500) + 10

for p in [0.25, 0.4, 0.7]:
  out, _ = dropout_forward(x, {'mode': 'train', 'p': p})
  out_test, _ = dropout_forward(x, {'mode': 'test', 'p': p})

  print('Running tests with p = ', p)
  print('Mean of input: ', x.mean())
  print('Mean of train-time output: ', out.mean())
  print('Mean of test-time output: ', out_test.mean())
  print('Fraction of train-time output set to zero: ', (out == 0).mean())
  print('Fraction of test-time output set to zero: ', (out_test == 0).mean())
  print()
# Out:
# Running tests with p =  0.25
# Mean of input:  10.0002078784775
# Mean of train-time output:  10.014059116977283
# Mean of test-time output:  10.0002078784775
# Fraction of train-time output set to zero:  0.749784
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.4
# Mean of input:  10.0002078784775
# Mean of train-time output:  9.977917658761159
# Mean of test-time output:  10.0002078784775
# Fraction of train-time output set to zero:  0.600796
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.7
# Mean of input:  10.0002078784775
# Mean of train-time output:  9.987811912159428
# Mean of test-time output:  10.0002078784775
# Fraction of train-time output set to zero:  0.30074
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# Реализуйте обратный проход для dropout-слоя

# %%
np.random.seed(231)
x = np.random.randn(10, 10) + 10
dout = np.random.randn(*x.shape)

dropout_param = {'mode': 'train', 'p': 0.2, 'seed': 123}
out, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
dx_num = eval_numerical_gradient_array(lambda xx: dropout_forward(xx, dropout_param)[0], x, dout)

# Error should be around e-10 or less
print('dx relative error: ', rel_error(dx, dx_num))
# Out:
# dx relative error:  5.44560814873387e-11

# %% [markdown]
# Добавьте в реализацию класса FullyConnectedNet поддержку dropout. Если параметр dropout != 1, то добавьте в модель dropout-слой после каждого слоя активации. Проверьте свою реализацию

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for dropout in [1, 0.75, 0.5]:
  print('Running check with dropout = ', dropout)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dtype=np.float64,
                            dropout=dropout, seed=123)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)
  
  # Relative errors should be around e-6 or less; Note that it's fine
  # if for dropout=1 you have W2 error be on the order of e-5.
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
  print()
# Out:
# Running check with dropout =  1
# Initial loss:  2.3004790897684924
# W1 relative error: 1.48e-07
# W2 relative error: 2.21e-05
# W3 relative error: 3.53e-07
# b1 relative error: 5.38e-09
# b2 relative error: 2.09e-09
# b3 relative error: 5.80e-11
#
# Running check with dropout =  0.75
# Initial loss:  2.302371489704412
# W1 relative error: 1.90e-07
# W2 relative error: 4.76e-06
# W3 relative error: 2.60e-08
# b1 relative error: 4.73e-09
# b2 relative error: 1.82e-09
# b3 relative error: 1.70e-10
#
# Running check with dropout =  0.5
# Initial loss:  2.3042759220785896
# W1 relative error: 3.11e-07
# W2 relative error: 1.84e-08
# W3 relative error: 5.35e-08
# b1 relative error: 2.58e-08
# b2 relative error: 2.99e-09
# b3 relative error: 1.13e-10

# %% [markdown]
# Обучите две двухслойные сети с dropout-слоем (вероятность отсева 0,25) и без на наборе из 500 изображений. Визуализируйте графики обучения. Сделайте выводы по результатам эксперимента

# %%
# Train two identical nets, one with dropout and one without
np.random.seed(231)
num_train = 500
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}
dropout_choices = [1, 0.25]
for dropout in dropout_choices:
  model = FullyConnectedNet([500], dropout=dropout)
  print(dropout)

  solver = Solver(model, small_data,
                  num_epochs=25, batch_size=100,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 5e-4,
                  },
                  verbose=True, print_every=100)
  solver.train()
  solvers[dropout] = solver
  print()
# Out:
# 1
# (Iteration 1 / 125) loss: 8.758436
# (Epoch 0 / 25) train acc: 0.284000; val_acc: 0.192000
# (Epoch 1 / 25) train acc: 0.354000; val_acc: 0.216400
# (Epoch 2 / 25) train acc: 0.484000; val_acc: 0.273400
# (Epoch 3 / 25) train acc: 0.614000; val_acc: 0.255600
# (Epoch 4 / 25) train acc: 0.676000; val_acc: 0.275600
# (Epoch 5 / 25) train acc: 0.742000; val_acc: 0.281400
# (Epoch 6 / 25) train acc: 0.838000; val_acc: 0.275400
# (Epoch 7 / 25) train acc: 0.854000; val_acc: 0.271400
# (Epoch 8 / 25) train acc: 0.884000; val_acc: 0.262600
# (Epoch 9 / 25) train acc: 0.902000; val_acc: 0.271400
# (Epoch 10 / 25) train acc: 0.914000; val_acc: 0.270800
# (Epoch 11 / 25) train acc: 0.930000; val_acc: 0.268200
# (Epoch 12 / 25) train acc: 0.934000; val_acc: 0.280200
# (Epoch 13 / 25) train acc: 0.942000; val_acc: 0.289400
# (Epoch 14 / 25) train acc: 0.958000; val_acc: 0.282200
# (Epoch 15 / 25) train acc: 0.966000; val_acc: 0.273400
# (Epoch 16 / 25) train acc: 0.988000; val_acc: 0.284200
# (Epoch 17 / 25) train acc: 0.974000; val_acc: 0.289000
# (Epoch 18 / 25) train acc: 0.996000; val_acc: 0.298000
# (Epoch 19 / 25) train acc: 0.984000; val_acc: 0.290400
# (Epoch 20 / 25) train acc: 0.984000; val_acc: 0.295400
# (Iteration 101 / 125) loss: 0.111547
# (Epoch 21 / 25) train acc: 0.998000; val_acc: 0.296400
# (Epoch 22 / 25) train acc: 0.996000; val_acc: 0.294800
# (Epoch 23 / 25) train acc: 0.996000; val_acc: 0.291800
# (Epoch 24 / 25) train acc: 0.992000; val_acc: 0.290400
# (Epoch 25 / 25) train acc: 1.000000; val_acc: 0.287600
#
# 0.25
# (Iteration 1 / 125) loss: 16.171768
# (Epoch 0 / 25) train acc: 0.248000; val_acc: 0.204400
# (Epoch 1 / 25) train acc: 0.342000; val_acc: 0.229600
# (Epoch 2 / 25) train acc: 0.432000; val_acc: 0.258800
# (Epoch 3 / 25) train acc: 0.520000; val_acc: 0.260200
# (Epoch 4 / 25) train acc: 0.564000; val_acc: 0.291800
# (Epoch 5 / 25) train acc: 0.588000; val_acc: 0.297000
# (Epoch 6 / 25) train acc: 0.618000; val_acc: 0.294400
# (Epoch 7 / 25) train acc: 0.632000; val_acc: 0.285200
# (Epoch 8 / 25) train acc: 0.712000; val_acc: 0.295200
# (Epoch 9 / 25) train acc: 0.770000; val_acc: 0.299600
# (Epoch 10 / 25) train acc: 0.742000; val_acc: 0.299400
# (Epoch 11 / 25) train acc: 0.764000; val_acc: 0.297000
# (Epoch 12 / 25) train acc: 0.800000; val_acc: 0.296800
# (Epoch 13 / 25) train acc: 0.778000; val_acc: 0.297400
# (Epoch 14 / 25) train acc: 0.816000; val_acc: 0.304600
# (Epoch 15 / 25) train acc: 0.834000; val_acc: 0.306000
# (Epoch 16 / 25) train acc: 0.850000; val_acc: 0.311200
# (Epoch 17 / 25) train acc: 0.842000; val_acc: 0.297800
# (Epoch 18 / 25) train acc: 0.848000; val_acc: 0.309600
# (Epoch 19 / 25) train acc: 0.888000; val_acc: 0.312600
# (Epoch 20 / 25) train acc: 0.886000; val_acc: 0.305800
# (Iteration 101 / 125) loss: 5.951317
# (Epoch 21 / 25) train acc: 0.882000; val_acc: 0.308000
# (Epoch 22 / 25) train acc: 0.920000; val_acc: 0.317000
# (Epoch 23 / 25) train acc: 0.870000; val_acc: 0.305800
# (Epoch 24 / 25) train acc: 0.920000; val_acc: 0.317000
# (Epoch 25 / 25) train acc: 0.882000; val_acc: 0.312200

# %%
# Plot train and validation accuracies of the two models

train_accs = []
val_accs = []
for dropout in dropout_choices:
  solver = solvers[dropout]
  train_accs.append(solver.train_acc_history[-1])
  val_accs.append(solver.val_acc_history[-1])

plt.subplot(3, 1, 1)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].train_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(3, 1, 2)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].val_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# ### Выводы по эксперименту
#
# В эксперименте сравнивались две одинаковые сети: одна без dropout, другая с dropout. Обучение проводилось на небольшой выборке из 500 изображений.
#
# Сеть без dropout быстрее обучалась на тренировочных данных и почти достигла 100% accuracy на train. Это означает, что модель сильно подстроилась под обучающую выборку и фактически начала запоминать изображения.
#
# Сеть с dropout обучалась медленнее. Ее train accuracy была ниже, примерно до 0.88–0.92, но качество на validation оказалось выше и стабильнее. По графику видно, что validation accuracy с dropout держалась примерно в диапазоне 0.30–0.32, тогда как без dropout результат чаще был ниже, около 0.28–0.30.
#
# Это показывает, что dropout работает как регуляризация. Во время обучения часть нейронов случайно отключается, поэтому сеть не может слишком сильно зависеть от отдельных признаков и вынуждена обучать более устойчивые представления.
#
# Итоговый вывод: dropout снизил переобучение. Без dropout сеть быстрее запоминает обучающую выборку, но хуже обобщает результат на новые данные. С dropout train accuracy ниже, зато validation accuracy выше, поэтому модель получается более устойчивой.

# %% [markdown]
# # Сверточные нейронные сети (CNN)

# %% [markdown]
# Реализуйте прямой проход для сверточного слоя - функция conv_forward_naive в scripts/layers.py юПроверьте свою реализацию, запустив код ниже

# %%
x_shape = (2, 3, 4, 4)
w_shape = (3, 3, 4, 4)
x = np.linspace(-0.1, 0.5, num=np.prod(x_shape)).reshape(x_shape)
w = np.linspace(-0.2, 0.3, num=np.prod(w_shape)).reshape(w_shape)
b = np.linspace(-0.1, 0.2, num=3)

conv_param = {'stride': 2, 'pad': 1}
out, _ = conv_forward_naive(x, w, b, conv_param)
correct_out = np.array([[[[-0.08759809, -0.10987781],
                           [-0.18387192, -0.2109216 ]],
                          [[ 0.21027089,  0.21661097],
                           [ 0.22847626,  0.23004637]],
                          [[ 0.50813986,  0.54309974],
                           [ 0.64082444,  0.67101435]]],
                         [[[-0.98053589, -1.03143541],
                           [-1.19128892, -1.24695841]],
                          [[ 0.69108355,  0.66880383],
                           [ 0.59480972,  0.56776003]],
                          [[ 2.36270298,  2.36904306],
                           [ 2.38090835,  2.38247847]]]])

# Compare your output to ours; difference should be around e-8
print('Testing conv_forward_naive')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing conv_forward_naive
# difference:  2.2121476417505994e-08

# %% [markdown]
# Реализуйте обратный проход - функция conv_backward_naive в scripts/layers.py

# %%
np.random.seed(231)
x = np.random.randn(4, 3, 5, 5)
w = np.random.randn(2, 3, 3, 3)
b = np.random.randn(2,)
dout = np.random.randn(4, 2, 5, 5)
conv_param = {'stride': 1, 'pad': 1}

dx_num = eval_numerical_gradient_array(lambda x: conv_forward_naive(x, w, b, conv_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_forward_naive(x, w, b, conv_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_forward_naive(x, w, b, conv_param)[0], b, dout)

out, cache = conv_forward_naive(x, w, b, conv_param)
dx, dw, db = conv_backward_naive(dout, cache)

# Your errors should be around e-8 or less.
print('Testing conv_backward_naive function')
print('dx error: ', rel_error(dx, dx_num))
print('dw error: ', rel_error(dw, dw_num))
print('db error: ', rel_error(db, db_num))
# Out:
# Testing conv_backward_naive function
# dx error:  1.7808556723954787e-08
# dw error:  3.2738772890979675e-10
# db error:  4.473566414430221e-11

# %% [markdown]
# Реализуйте прямой проход для max-pooling слоя -функция  max_pool_forward_naive в scripts/layers.py

# %%
x_shape = (2, 3, 4, 4)
x = np.linspace(-0.3, 0.4, num=np.prod(x_shape)).reshape(x_shape)
pool_param = {'pool_width': 2, 'pool_height': 2, 'stride': 2}

out, _ = max_pool_forward_naive(x, pool_param)

correct_out = np.array([[[[-0.26315789, -0.24842105],
                          [-0.20421053, -0.18947368]],
                         [[-0.14526316, -0.13052632],
                          [-0.08631579, -0.07157895]],
                         [[-0.02736842, -0.01263158],
                          [ 0.03157895,  0.04631579]]],
                        [[[ 0.09052632,  0.10526316],
                          [ 0.14947368,  0.16421053]],
                         [[ 0.20842105,  0.22315789],
                          [ 0.26736842,  0.28210526]],
                         [[ 0.32631579,  0.34105263],
                          [ 0.38526316,  0.4       ]]]])

# Compare your output with ours. Difference should be on the order of e-8.
print('Testing max_pool_forward_naive function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing max_pool_forward_naive function:
# difference:  4.1666665157267834e-08

# %% [markdown]
# Реализуйте обратный проход для max-pooling слоя в max_pool_backward_naive .

# %%
np.random.seed(231)
x = np.random.randn(3, 2, 8, 8)
dout = np.random.randn(3, 2, 4, 4)
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

dx_num = eval_numerical_gradient_array(lambda x: max_pool_forward_naive(x, pool_param)[0], x, dout)

out, cache = max_pool_forward_naive(x, pool_param)
dx = max_pool_backward_naive(dout, cache)

# Your error should be on the order of e-12
print('Testing max_pool_backward_naive function:')
print('dx error: ', rel_error(dx, dx_num))
# Out:
# Testing max_pool_backward_naive function:
# dx error:  3.27562514223145e-12

# %% [markdown]
# В скрипте scripts/fast_layers.py представлены быстрые реализации слоев свертки и пуллинга, написанных с использованием  Cython.
#
# Для компиляции выполните следующую команду в директории scripts
#
# ```bash
# python setup.py build_ext --inplace
# ```

# %% [markdown]
# Сравните ваши реализации слоев свертки и пуллинга с быстрыми реализациями.

# %%
# Rel errors should be around e-9 or less
# Исправление для случая, когда Cython-функция col2im_6d_cython не импортировалась.

import scripts.fast_layers as fast_layers

def col2im_6d_numpy(cols, N, C, H, W, HH, WW, pad, stride):
    """
    NumPy fallback для col2im_6d_cython.
    cols shape: (C, HH, WW, N, out_h, out_w)
    return shape: (N, C, H, W)
    """
    H_padded = H + 2 * pad
    W_padded = W + 2 * pad
    x_padded = np.zeros((N, C, H_padded, W_padded), dtype=cols.dtype)

    out_h = cols.shape[4]
    out_w = cols.shape[5]

    for hh in range(HH):
        for ww in range(WW):
            for i in range(out_h):
                row = i * stride + hh
                for j in range(out_w):
                    col = j * stride + ww
                    x_padded[:, :, row, col] += cols[:, hh, ww, :, i, j].T

    if pad == 0:
        return x_padded
    return x_padded[:, :, pad:-pad, pad:-pad]

if not hasattr(fast_layers, 'col2im_6d_cython'):
    fast_layers.col2im_6d_cython = col2im_6d_numpy

from scripts.fast_layers import conv_forward_fast, conv_backward_fast
from time import time

np.random.seed(231)
x = np.random.randn(100, 3, 31, 31)
w = np.random.randn(25, 3, 3, 3)
b = np.random.randn(25,)
dout = np.random.randn(100, 25, 16, 16)
conv_param = {'stride': 2, 'pad': 1}

t0 = time()
out_naive, cache_naive = conv_forward_naive(x, w, b, conv_param)
t1 = time()
out_fast, cache_fast = conv_forward_fast(x, w, b, conv_param)
t2 = time()

print('Testing conv_forward_fast:')
print('Naive: %fs' % (t1 - t0))
print('Fast: %fs' % (t2 - t1))
forward_fast_time = max(t2 - t1, 1e-12)
print('Speedup: %fx' % ((t1 - t0) / forward_fast_time))
print('Difference: ', rel_error(out_naive, out_fast))

t0 = time()
dx_naive, dw_naive, db_naive = conv_backward_naive(dout, cache_naive)
t1 = time()
dx_fast, dw_fast, db_fast = conv_backward_fast(dout, cache_fast)
t2 = time()

print('\nTesting conv_backward_fast:')
print('Naive: %fs' % (t1 - t0))
print('Fast: %fs' % (t2 - t1))
backward_fast_time = max(t2 - t1, 1e-12)
print('Speedup: %fx' % ((t1 - t0) / backward_fast_time))
print('dx difference: ', rel_error(dx_naive, dx_fast))
print('dw difference: ', rel_error(dw_naive, dw_fast))
print('db difference: ', rel_error(db_naive, db_fast))
# Out:
# Testing conv_forward_fast:
# Naive: 5.052114s
# Fast: 0.004588s
# Speedup: 1101.127676x
# Difference:  7.88225256277888e-11
#
# Testing conv_backward_fast:
# Naive: 2.920879s
# Fast: 0.023393s
# Speedup: 124.860413x
# dx difference:  1.50193951894836e-11
# dw difference:  2.538300430922586e-13
# db difference:  0.0

# %%
# Relative errors should be close to 0.0
from scripts.fast_layers import max_pool_forward_fast, max_pool_backward_fast
np.random.seed(231)
x = np.random.randn(100, 3, 32, 32)
dout = np.random.randn(100, 3, 16, 16)
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

t0 = time()
out_naive, cache_naive = max_pool_forward_naive(x, pool_param)
t1 = time()
out_fast, cache_fast = max_pool_forward_fast(x, pool_param)
t2 = time()

print('Testing pool_forward_fast:')
print('Naive: %fs' % (t1 - t0))
print('fast: %fs' % (t2 - t1))
print('speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('difference: ', rel_error(out_naive, out_fast))

t0 = time()
dx_naive = max_pool_backward_naive(dout, cache_naive)
t1 = time()
dx_fast = max_pool_backward_fast(dout, cache_fast)
t2 = time()

print('\nTesting pool_backward_fast:')
print('Naive: %fs' % (t1 - t0))
print('fast: %fs' % (t2 - t1))
print('speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('dx difference: ', rel_error(dx_naive, dx_fast))
# Out:
# Testing pool_forward_fast:
# Naive: 0.156393s
# fast: 0.005294s
# speedup: 29.542425x
# difference:  0.0
#
# Testing pool_backward_fast:
# Naive: 0.449780s
# fast: 0.008656s
# speedup: 51.961494x
# dx difference:  0.0

# %% [markdown]
# В layer_utils.py вы можете найти  часто используемые комбинации слоев, используемых в сверточных сетях. Ознакомьтесь с ними и запустите код ниже для проверки их работы

# %%
from scripts.layer_utils import conv_relu_pool_forward, conv_relu_pool_backward
np.random.seed(231)
x = np.random.randn(2, 3, 16, 16)
w = np.random.randn(3, 3, 3, 3)
b = np.random.randn(3,)
dout = np.random.randn(2, 3, 8, 8)
conv_param = {'stride': 1, 'pad': 1}
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

out, cache = conv_relu_pool_forward(x, w, b, conv_param, pool_param)
dx, dw, db = conv_relu_pool_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], b, dout)

# Relative errors should be around e-8 or less
print('Testing conv_relu_pool')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing conv_relu_pool
# dx error:  1.3129103487372312e-08
# dw error:  4.243260484602694e-09
# db error:  3.579585075287619e-10

# %%
from scripts.layer_utils import conv_relu_forward, conv_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 8, 8)
w = np.random.randn(3, 3, 3, 3)
b = np.random.randn(3,)
dout = np.random.randn(2, 3, 8, 8)
conv_param = {'stride': 1, 'pad': 1}

out, cache = conv_relu_forward(x, w, b, conv_param)
dx, dw, db = conv_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: conv_relu_forward(x, w, b, conv_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_relu_forward(x, w, b, conv_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_relu_forward(x, w, b, conv_param)[0], b, dout)

# Relative errors should be around e-8 or less
print('Testing conv_relu:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing conv_relu:
# dx error:  5.532043677351017e-09
# dw error:  2.556001426075349e-10
# db error:  1.1891655515776076e-10

# %% [markdown]
# Напишите реализацию класса ThreeLayerConvNet в scripts/classifiers/cnn.py . Вы можете использовать готовые реализации слоев и их комбинаций.

# %% [markdown]
# Проверьте вашу реализацию. Ожидается, что значение функции потерь softmax будет порядка `log(C)` для `C` классов для случая без регуляризации. В случае регуляризации значение функции потерь должно немного возрасти.

# %%
model = ThreeLayerConvNet()

N = 50
X = np.random.randn(N, 3, 32, 32)
y = np.random.randint(10, size=N)

loss, grads = model.loss(X, y)
print('Initial loss (no regularization): ', loss)

model.reg = 0.5
loss, grads = model.loss(X, y)
print('Initial loss (with regularization): ', loss)
# Out:
# Initial loss (no regularization):  2.302586071243987
# Initial loss (with regularization):  2.5082556233317708

# %% [markdown]
# Проверьте реализацию обратного прохода

# %%
num_inputs = 2
input_dim = (3, 16, 16)
reg = 0.0
num_classes = 10
np.random.seed(231)
X = np.random.randn(num_inputs, *input_dim)
y = np.random.randint(num_classes, size=num_inputs)

model = ThreeLayerConvNet(num_filters=3, filter_size=3,
                          input_dim=input_dim, hidden_dim=7,
                          dtype=np.float64)
loss, grads = model.loss(X, y)
# Errors should be small, but correct implementations may have
# relative errors up to the order of e-2
for param_name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    param_grad_num = eval_numerical_gradient(f, model.params[param_name], verbose=False, h=1e-6)
    e = rel_error(param_grad_num, grads[param_name])
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 1.380104e-04
# W2 max relative error: 1.822723e-02
# W3 max relative error: 3.064049e-04
# b1 max relative error: 3.477652e-05
# b2 max relative error: 2.516375e-03
# b3 max relative error: 7.945660e-10

# %% [markdown]
# Попробуйте добиться эффекта переобучения. Обучите модель на небольшом наборе данных.Сравните значения accuracy на обучающих данных и на валидационных. Визуализируйте графики обучения

# %%
np.random.seed(231)

num_train = 100
small_data = {
  'X_train': X_train[:num_train].reshape(num_train, 3, 32, 32),
  'y_train': y_train[:num_train],
  'X_val': X_val.reshape(X_val.shape[0], 3, 32, 32),
  'y_val': y_val,
}

model = ThreeLayerConvNet(weight_scale=1e-2)

solver = Solver(model, small_data,
                num_epochs=15, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=1)
solver.train()
# Out:
# (Iteration 1 / 30) loss: 2.272878
# (Epoch 0 / 15) train acc: 0.130000; val_acc: 0.103800
# (Iteration 2 / 30) loss: 6.418379
# (Epoch 1 / 15) train acc: 0.160000; val_acc: 0.097600
# (Iteration 3 / 30) loss: 4.341172
# (Iteration 4 / 30) loss: 3.474702
# (Epoch 2 / 15) train acc: 0.160000; val_acc: 0.116200
# (Iteration 5 / 30) loss: 3.345452
# (Iteration 6 / 30) loss: 3.104953
# (Epoch 3 / 15) train acc: 0.290000; val_acc: 0.117600
# (Iteration 7 / 30) loss: 2.464576
# (Iteration 8 / 30) loss: 2.146098
# (Epoch 4 / 15) train acc: 0.260000; val_acc: 0.144800
# (Iteration 9 / 30) loss: 2.280514
# (Iteration 10 / 30) loss: 2.198593
# (Epoch 5 / 15) train acc: 0.250000; val_acc: 0.133800
# (Iteration 11 / 30) loss: 2.206614
# (Iteration 12 / 30) loss: 2.369653
# (Epoch 6 / 15) train acc: 0.240000; val_acc: 0.134400
# (Iteration 13 / 30) loss: 2.337212
# (Iteration 14 / 30) loss: 2.058478
# (Epoch 7 / 15) train acc: 0.280000; val_acc: 0.127600
# (Iteration 15 / 30) loss: 2.038651
# (Iteration 16 / 30) loss: 2.020532
# (Epoch 8 / 15) train acc: 0.340000; val_acc: 0.156200
# (Iteration 17 / 30) loss: 2.011035
# (Iteration 18 / 30) loss: 2.113889
# (Epoch 9 / 15) train acc: 0.340000; val_acc: 0.148200
# (Iteration 19 / 30) loss: 1.856983
# (Iteration 20 / 30) loss: 1.961519
# (Epoch 10 / 15) train acc: 0.340000; val_acc: 0.138400
# (Iteration 21 / 30) loss: 1.938571
# (Iteration 22 / 30) loss: 1.532032
# (Epoch 11 / 15) train acc: 0.380000; val_acc: 0.140800
# (Iteration 23 / 30) loss: 1.703401
# (Iteration 24 / 30) loss: 1.637834
# (Epoch 12 / 15) train acc: 0.380000; val_acc: 0.149200
# (Iteration 25 / 30) loss: 1.589979
# (Iteration 26 / 30) loss: 1.744386
# (Epoch 13 / 15) train acc: 0.420000; val_acc: 0.159000
# (Iteration 27 / 30) loss: 1.604305
# (Iteration 28 / 30) loss: 1.498529
# (Epoch 14 / 15) train acc: 0.390000; val_acc: 0.159200
# (Iteration 29 / 30) loss: 1.220565
# (Iteration 30 / 30) loss: 1.645512
# (Epoch 15 / 15) train acc: 0.410000; val_acc: 0.151600

# %%
# Print final training accuracy
print(
    "Small data training accuracy:",
    solver.check_accuracy(small_data['X_train'], small_data['y_train'])
)
# Out:
# Small data training accuracy: 0.39

# %%
# Print final validation accuracy
print(
    "Small data validation accuracy:",
    solver.check_accuracy(small_data['X_val'], small_data['y_val'])
)
# Out:
# Small data validation accuracy: 0.1592

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# Обучите сеть на полном наборе данных. Выведите accuracy на обучающей и валидационной выборках

# %%
model = ThreeLayerConvNet(weight_scale=0.001, hidden_dim=500, reg=0.001)

cnn_data = {
    'X_train': X_train.reshape(X_train.shape[0], 3, 32, 32),
    'y_train': y_train,
    'X_val': X_val.reshape(X_val.shape[0], 3, 32, 32),
    'y_val': y_val,
}

solver = Solver(model, cnn_data,
                num_epochs=1, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=20)
solver.train()
# Out:
# (Iteration 1 / 900) loss: 2.304567
# (Epoch 0 / 1) train acc: 0.125000; val_acc: 0.123800
# (Iteration 21 / 900) loss: 2.208224
# (Iteration 41 / 900) loss: 2.150305
# (Iteration 61 / 900) loss: 2.112025
# (Iteration 81 / 900) loss: 2.180069
# (Iteration 101 / 900) loss: 2.053108
# (Iteration 121 / 900) loss: 1.989750
# (Iteration 141 / 900) loss: 2.067219
# (Iteration 161 / 900) loss: 2.251633
# (Iteration 181 / 900) loss: 1.978601
# (Iteration 201 / 900) loss: 2.029680
# (Iteration 221 / 900) loss: 2.124360
# (Iteration 241 / 900) loss: 1.836124
# (Iteration 261 / 900) loss: 1.996824
# (Iteration 281 / 900) loss: 1.860808
# (Iteration 301 / 900) loss: 1.984138
# (Iteration 321 / 900) loss: 1.858060
# (Iteration 341 / 900) loss: 1.919948
# (Iteration 361 / 900) loss: 2.086093
# (Iteration 381 / 900) loss: 1.728412
# (Iteration 401 / 900) loss: 2.012037
# (Iteration 421 / 900) loss: 1.993870
# (Iteration 441 / 900) loss: 1.654987
# (Iteration 461 / 900) loss: 1.988585
# (Iteration 481 / 900) loss: 2.213144
# (Iteration 501 / 900) loss: 2.243895
# (Iteration 521 / 900) loss: 1.715494
# (Iteration 541 / 900) loss: 1.806574
# (Iteration 561 / 900) loss: 1.733298
# (Iteration 581 / 900) loss: 1.956135
# (Iteration 601 / 900) loss: 1.889714
# (Iteration 621 / 900) loss: 1.710661
# (Iteration 641 / 900) loss: 2.073831
# (Iteration 661 / 900) loss: 1.791130
# (Iteration 681 / 900) loss: 1.779161
# (Iteration 701 / 900) loss: 1.912148
# (Iteration 721 / 900) loss: 1.712285
# (Iteration 741 / 900) loss: 2.122458
# (Iteration 761 / 900) loss: 1.802861
# (Iteration 781 / 900) loss: 1.768919
# (Iteration 801 / 900) loss: 1.826846
# (Iteration 821 / 900) loss: 1.614669
# (Iteration 841 / 900) loss: 1.944437
# (Iteration 861 / 900) loss: 1.687497
# (Iteration 881 / 900) loss: 1.920900
# (Epoch 1 / 1) train acc: 0.309000; val_acc: 0.310000

# %%
# Print final training accuracy
print(
    "Full data training accuracy:",
    solver.check_accuracy(cnn_data['X_train'], cnn_data['y_train'])
)
# Out:
# Full data training accuracy: 0.30722222222222223

# %%
# Print final validation accuracy
print(
    "Full data validation accuracy:",
    solver.check_accuracy(cnn_data['X_val'], cnn_data['y_val'])
)
# Out:
# Full data validation accuracy: 0.31

# %% [markdown]
# Визуализируйте фильтры на первом слое обученной сети

# %%
from scripts.vis_utils import visualize_grid

grid = visualize_grid(model.params['W1'].transpose(0, 2, 3, 1))
plt.imshow(grid.astype('uint8'))
plt.axis('off')
plt.gcf().set_size_inches(5, 5)
plt.show()
